# %%
from visualizacion.visualizacion import Visualizador

vis = Visualizador("STEVEN\\SQLEXPRESS")
vis.cargar_tabla("consumo")
vis.df.head()
# Out:
#             fechaHora       MW                time  cloud_cover  \
# 0 2023-01-01 00:00:00  1023.34 2023-01-01 00:00:00           15
# 1 2023-01-01 01:00:00   994.38 2023-01-01 01:00:00           99
# 2 2023-01-01 02:00:00   945.35 2023-01-01 02:00:00           65
# 3 2023-01-01 03:00:00   909.23 2023-01-01 03:00:00           19
# 4 2023-01-01 04:00:00   887.49 2023-01-01 04:00:00           41
#
#    precipitation  apparent_temperature  wind_speed_10m  sunshine_duration  \
# 0            0.0                  27.7            21.4               0.00
# 1            0.0                  27.8            20.9               0.00
# 2            0.0                  27.8            22.1            3457.26
# 3            0.0                  27.7            23.2            3600.00
# 4            0.0                  27.9            23.3            3600.00
#
#    mes  dia_mes  hora  dia_sem  anio
# 0    1        1     0        6  2023
# 1    1        1     1        6  2023
# ...

# %%
##Promedio de potencia eléctrica por hora del día
vis.grafico_mw_por_hora()

# %%
### Promedio de potencia eléctrica por mes del año
vis.grafico_mw_por_mes()

# %%
 #### Relación entre temperatura y potencia eléctrica
 vis.grafico_mw_vs_temp()

# %%
### Relación entre nubosidad y potencia eléctrica
vis.grafico_mw_vs_nubes()
