# %%
####importamos
from eda.EDA import ProcesadorEDA

eda = ProcesadorEDA("STEVEN\\SQLEXPRESS")
eda.cargar_tabla("consumo")

# %%
### estadisticas basicas
eda.estadisticas()
# Out:
#                  fechaHora            MW                 time   cloud_cover  \
# count                17544  17544.000000                17544  17544.000000
# mean   2024-01-01 11:30:00   1437.083018  2024-01-01 11:30:00     71.728682
# min    2023-01-01 00:00:00    833.240000  2023-01-01 00:00:00      0.000000
# 25%    2023-07-02 17:45:00   1200.692500  2023-07-02 17:45:00     38.000000
# 50%    2024-01-01 11:30:00   1479.865000  2024-01-01 11:30:00     96.000000
# 75%    2024-07-02 05:15:00   1656.202500  2024-07-02 05:15:00    100.000000
# max    2024-12-31 23:00:00   1922.780000  2024-12-31 23:00:00    100.000000
# std                    NaN    249.359659                  NaN     35.902265
#
#        precipitation  apparent_temperature  wind_speed_10m  sunshine_duration  \
# count   17544.000000          17544.000000    17544.000000       17544.000000
# mean        0.202251             31.364888       23.110209        1460.042674
# ...

# %%
####correlaciones
eda.correlacion()
# Out:
#                             MW  cloud_cover  precipitation  \
# MW                    1.000000    -0.006695      -0.021177
# cloud_cover          -0.006695     1.000000       0.182705
# precipitation        -0.021177     0.182705       1.000000
# apparent_temperature  0.125552    -0.121269      -0.218206
# wind_speed_10m       -0.107660     0.238399       0.061078
# sunshine_duration    -0.288858    -0.150437      -0.121247
# mes                  -0.038239     0.269009       0.155154
# dia_mes              -0.000617    -0.053450       0.009809
# hora                  0.596470     0.035642       0.004736
# dia_sem              -0.187667    -0.020748      -0.040162
# anio                  0.099470     0.028382      -0.018670
#
#                       apparent_temperature  wind_speed_10m  sunshine_duration  \
# MW                                0.125552       -0.107660          -0.288858
# cloud_cover                      -0.121269        0.238399          -0.150437
# ...

# %%
### mapa de correlaciones
eda.grafico_correlacion()
